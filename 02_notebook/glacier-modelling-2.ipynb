# %% [markdown]
# # Notebook 2
#
# - If you work on Google Colab, [![open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](
# https://colab.research.google.com/github/jouvetg/glamod/blob/main/02_notebook/glacier-modelling-2.ipynb) and you will donwload the repo  below. Make sure to activate the GPU on Colab "Runtime" -> "Change Runtime Type" -> Slect GPU.
#
# - If you work locally on your own PC, you can download the repo
# ```bash
# git clone --depth 1 https://github.com/jouvetg/glamod.git
# ```
# and then go the notebook folder, and work from there.

# %% [markdown]
# ## Goals of this notebook
#
#    - Get familiar with model IGM
#    - Understand the parameters, set-up your model
#    - Run IGM examples
#    - Customization, run IGM for your own glacier

# %% [markdown]
# ## What is IGM?
#
# Here we will use the glacier evolution model developed at UNIL -- the Instructed Glacier Model.
#
# The IGM is an open-source Python package, which permits to simulate 3D glacier evolution accounting for the coupling between ice thermo-dynamics, surface mass balance, and mass conservation. IGM is especially computationally efficient thanks to the TensorFlow library, mathematical operations are fully-vectorized. This permits important speed-ups on [GPU](https://en.wikipedia.org/wiki/Graphics_processing_unit) (Graphics Processing Units), which are devices made of many processors, and can therefore perform highly-parallelized computations.
#
# All the documentation can be found at [https://igm-model.org/](https://igm-model.org/).

# %% [markdown]
# ## How to install IGM?
#
# Running IGM consists of running a python script `igm_run`, which is made of functions of the `igm` python package.  First of all, one needs to install igm as follows: (this may take a while, and it may crashes the first time, but should work the second time).

# %%
! pip install -i https://test.pypi.org/simple/ --extra-index-url https://pypi.org/simple igm-model-testing-package==3.0.5
# Out:
# Looking in indexes: https://test.pypi.org/simple/, https://pypi.org/simple
# Requirement already satisfied: igm-model-testing-package==3.0.5 in /usr/local/lib/python3.12/dist-packages (3.0.5)
# Requirement already satisfied: tensorflow==2.17.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.17.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.16.2)
# Requirement already satisfied: netCDF4==1.6.0 in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.6.0)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (2025.10.1)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.4.3)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (3.7.2)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.1.1)
# Requirement already satisfied: oggm in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.6.2)
# Requirement already satisfied: salem in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (0.3.11)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (6.0.3)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (6.5.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (4.67.1)
# Requirement already satisfied: hydra-core in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.3.2)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (2.3.0)
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.12/dist-packages (from netCDF4==1.6.0->igm-model-testing-package==3.0.5) (1.26.4)
# Requirement already satisfied: cftime in /usr/local/lib/python3.12/dist-packages (from netCDF4==1.6.0->igm-model-testing-package==3.0.5) (1.6.5)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.15.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (1.75.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.10.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.3.4.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.3.4.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.3.101 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.3.101)
# Requirement already satisfied: nvidia-cuda-nvcc-cu12==12.3.107 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.3.107)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.3.107 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.3.107)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.3.101 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.3.101)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.7.29 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (8.9.7.29)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.12.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (11.0.12.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.4.107 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (10.3.4.107)
# Requirement already satisfied: nvidia-cusolver-cu12==11.5.4.101 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (11.5.4.101)
# Requirement already satisfied: nvidia-cusparse-cu12==12.2.0.103 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.2.0.103)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.19.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.3.101 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.3.101)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas->igm-model-testing-package==3.0.5) (0.11.1)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->igm-model-testing-package==3.0.5) (2.2.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->igm-model-testing-package==3.0.5) (2.1.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj->igm-model-testing-package==3.0.5) (2025.10.5)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core->igm-model-testing-package==3.0.5) (4.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (2.9.0.post0)
# Requirement already satisfied: configobj in /usr/local/lib/python3.12/dist-packages (from oggm->igm-model-testing-package==3.0.5) (5.0.9)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (25.4.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (8.3.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (0.7.2)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (1.1.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from salem->igm-model-testing-package==3.0.5) (1.5.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.17.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas->igm-model-testing-package==3.0.5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas->igm-model-testing-package==3.0.5) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.5.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.1.2)

# %% [markdown]
# In this notebook, we will explore 3 model runs with increasing complexity:
#
# - A first basic run with a simple surface mass balance model
# - A second one that works for any glacier, with a more elaborate SMB
# - A third with a user-defined SMB and particle tracking

# %% [markdown]
# ## Download the data

# %% [markdown]
# Let's now download the repo with the data if you are using Colab

# %%
import sys, os

if "google.colab" in sys.modules:
    print("Running in Colab: cloning repo...")
    # !git clone --depth 1 https://github.com/jouvetg/glamod.git
    # !apt-get install tree -q
else:
    print("Running locally: using local files.")
# Out:
# Running in Colab: cloning repo...
# Cloning into 'glamod'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 69 (delta 5), reused 58 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (69/69), 14.04 MiB | 9.92 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 1s (79.5 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 126675 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# Let's now go the working folder

# %%
if "google.colab" in sys.modules:
    # %cd /content/glamod/02_notebook
# Out:
# /content/glamod/02_notebook

# %% [markdown]
# ## First run with IGM

# %% [markdown]
# ### Folder exploration
#
# Let us explore the directory with the following command:

# %%
# !tree
# Out:
# .
# ├── data
# │   └── input-aletsch.nc
# ├── experiment
# │   ├── params_0.yaml
# │   ├── params_1.yaml
# │   └── params_2.yaml
# ├── glacier-modelling-2.ipynb
# ├── helper.py
# └── user
#     ├── code
#     │   └── processes
#     │       └── mysmb.py
#     └── conf
#         └── processes
#             └── mysmb.yaml
#
# 7 directories, 8 files

# %% [markdown]
# You will see the following files :
#
# ```bash
# .
# ├── data                 # This folder contains all input data
# ├── experiment           # This folder contains the parameters
# │   ├── params_0.yaml
# │   ├── ...
# └── user                 # This folder contains user code
#     ├── code
#     └── conf
# ```

# %% [markdown]
# ### Parameter file exploration
#
# If you look at the parameter file, you will see the following content, which shows all the input, process, and output modules along with all their parameters. Below, you may notice that IGM: i) first loads a certain number of inputs, processes, and output modules, ii) second defines parameters associated with each module that deviate from default ones.
#
# Here is the content of `params_0.yaml`, taken from IGM's example `aletsch-basic`. Here, IGM loads data with the `local` module, proceeds to a simulation from 1900 to 2000 updating surface mass balance (`smb`), iceflow, time, and ice thickness. Then, it writes the results in both a local file (NetCDF file) and in the form of plots.
#
# ```yaml title="params_0.yaml"
# # @package _global_
#
# defaults:
#   - override /inputs:
#     - local                    # load local input module
#   - override /processes:
#     - smb_simple               # load smb_simple processes module
#     - iceflow                  # load iceflow processes module
#     - time                     # load time processes module
#     - thk                      # load thk processes module
#   - override /outputs:
#     - local                    # load local outputs module
#     - plot2d                   # load plot2d outputs module
#
# inputs:
#   local:
#      filename: input-aletsch.nc   # The local model will load the input-aletsch.nc file
#
# processes:
#   smb_simple:
#     array:
#       - ["time", "gradabl", "gradacc", "ela", "accmax"]
#       - [1900, 0.009, 0.005, 2800, 2.0]
#       - [2000, 0.009, 0.005, 2900, 2.0]
#       - [2100, 0.009, 0.005, 3300, 2.0]
#   time:
#     start: 1900.0
#     end: 2000.0
#     save: 10.0
#
# outputs:
#   plot2d:
#     live: False
# ```

# %% [markdown]
# * gradabl = grad for ablation
#
#
# * gradacc = grad for accumulation
# * ela = ELA
# * accmax ??

# %% [markdown]
# IGM is organized **module-wise** as shown in the following flowchart:
#
# ![](https://igm-model.org/latest/modules/flowchat-module.png)
#
# As a user, you need to pick an ensemble of modules from existing ones (or you may create some user ones), and then define the parameters that deviate from default ones.

# %% [markdown]
# ### Exploring the data (`input.nc`)
#
# Before running IGM, it's useful to explore the input data file. The `input.nc` file is a NetCDF file that contains all the necessary spatial data for the glacier simulation, such as the bed topography, initial ice thickness, and other geographic information.
#
# We can use the `xarray` library to easily load and explore NetCDF files. Let's look at what's inside the `input.nc` file:

# %%
import xarray as xr
import matplotlib.pyplot as plt

# Load the NetCDF file
ds = xr.open_dataset('data/input-aletsch.nc')

# Display the dataset structure
print("Dataset structure:")
print(ds)
print("\n" + "="*60 + "\n")

# Show data variables
print("Data variables:")
for var in ds.data_vars:
    print(f"  - {var}: {ds[var].attrs.get('long_name', 'No description')}")
    print(f"    Shape: {ds[var].shape}, Units: {ds[var].attrs.get('units', 'N/A')}")
print("\n" + "="*60 + "\n")
# Out:
# Dataset structure:
# <xarray.Dataset> Size: 526kB
# Dimensions:  (y: 244, x: 179)
# Coordinates:
#   * y        (y) float32 976B 5.136e+06 5.136e+06 ... 5.16e+06 5.16e+06
#   * x        (x) float32 716B 4.15e+05 4.151e+05 ... 4.327e+05 4.328e+05
# Data variables:
#     usurf    (y, x) float32 175kB ...
#     thk      (y, x) float32 175kB ...
#     icemask  (y, x) float32 175kB ...
#
# ============================================================
#
# Data variables:
#   - usurf: Surface Topography
#     Shape: (244, 179), Units: m
#   - thk: Ice Thickness
#     Shape: (244, 179), Units: m
#   - icemask: Ice mask
#     Shape: (244, 179), Units: no unit
#
# ============================================================

# %% [markdown]
# Now let's visualize some of the key fields in the input data:

# %%
# Create a figure with multiple subplots to visualize the data
fig, axes = plt.subplots(1, 3, figsize=(14, 5))

# Plot bed topography (topg)
ds['usurf'].plot(ax=axes[0], cmap='terrain')
axes[0].set_title('Surface Topography')
axes[0].set_aspect('equal')

# Plot ice thickness (thk)
ds['thk'].plot(ax=axes[1], cmap='Blues')
axes[1].set_title('Ice Thickness')
axes[1].set_aspect('equal')

# Plot ice mask
ds['icemask'].plot(ax=axes[2], cmap='gray')
axes[2].set_title('Ice Mask')
axes[2].set_aspect('equal')

plt.tight_layout()
plt.show()

# %% [markdown]
# What you see above shows raster grids of top surface elevation, ice thickness, and ice mask for the Aletsch Glacier at a spatial resolution of 100 m.

# %% [markdown]
# ### 'Simple' Surface Mass Balance
#
# The snow accumulation budget (which turns into ice) at altitude and ice melt depends on precipitation and temperature. This mass balance $SMB(z)$ is commonly defined as a function of altitude and depends on different factors:
#
# - A slope that controls the mass balance gradients in both the accumulation $b_\mathrm{acc}$ and the ablation area $b_\mathrm{abl}$
# - A maximum value for accumulation $b_\mathrm{max}$
# - The altitude of the equilibrium line $z_\mathrm{ELA}$ beyond which ice accumulates and below which ice melts
#
# Mathematically, $SMB(z)$ can be expressed as a piecewise function:
#
# $$
# SMB(z) = \begin{cases}
# b_\mathrm{abl} \cdot (z - z_\mathrm{ELA}) & \text{if } z < z_\mathrm{ELA} \text{ (ablation zone)} \\
# \min(b_\mathrm{acc} \cdot (z - z_\mathrm{ELA}), b_\mathrm{max}) & \text{if } z \geq z_\mathrm{ELA} \text{ (accumulation zone)}
# \end{cases}
# $$
#
# The code in the next block gives an example of SMB function as a function of elevation $z$.

# %%
import numpy as np
import matplotlib.pyplot as plt

z_ELA=3000.0
grad_abl=0.009
grad_acc=0.005
b_max=2.0

def smb_fct(elev):
    smb = elev - z_ELA
    smb *= np.where(smb < 0, grad_abl, grad_acc)
    return np.minimum(smb, b_max)

elev = np.arange(2000.0, 4000.0, 20.0)
plt.axhline(y=z_ELA, color='r', linestyle='--', label='ELA')
plt.plot(smb_fct(elev), elev)
plt.ylabel('Altitude [m]')
plt.xlabel('SMB [m/y]')
plt.title('Example of SMB as a function of elevation')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### Running IGM (`params_0`)
#
# Now, we can run IGM by simply running the command `igm_run +experiment=params_0` (or replace `params_0` with the actual name of your parameter file) in the corresponding folder to execute the example. This will model the evolution of Aletsch Glacier for 100 years given the Surface Mass Balance parameters specified in the parameter file.

# %%
# !igm_run +experiment=params_0
# Out:
# 2025-10-22 06:51:16.058139: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-22 06:51:16.091309: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-22 06:51:16.101061: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-22 06:51:16.125226: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-22 06:51:17.765534: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761115883.180422    2451 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761115883.765331    2451 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761115883.765668    2451 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# -------------------------------------------------------------------CUDA Enviroment--------------------------------------------------------------------
# {
#   "cpu_compiler": "/usr/lib/llvm-17/bin/clang",
#   "cuda_version": "12.3",
#   "cudnn_version": "8",
#   "is_cuda_build": true,
#   "is_rocm_build": false,
#   "is_tensorrt_build": true
# }
# ----------------------------------------------------------------Available GPU Devices-----------------------------------------------------------------
# I0000 00:00:1761115883.766188    2451 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# {
#   "gpu_id": "/physical_device:GPU:0",
#   "device_type": "GPU",
#   "compute_capability": [
#     7,
#     5
#   ],
#   "device_name": "Tesla T4"
# }
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# I0000 00:00:1761115883.767187    2451 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761115883.767457    2451 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761115883.767657    2451 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761115883.889120    2451 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761115883.889485    2451 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761115883.889748    2451 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-10-22 06:51:23.889912: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 1 Physical GPUs, 1 Logical GPU
# ----------------------------------------------------------------------------------------------------
# -------------------------------------------INPUTS Modules-------------------------------------------
#  0: <module 'igm.inputs.local' from '/usr/local/lib/python3.12/dist-packages/igm/inputs/local.py'>
# -----------------------------------------PROCESSES Modules------------------------------------------
#  0: <module 'igm.processes.smb_simple' from '/usr/local/lib/python3.12/dist-packages/igm/processes/smb_simple/__init__.py'>
#  1: <module 'igm.processes.iceflow' from '/usr/local/lib/python3.12/dist-packages/igm/processes/iceflow/__init__.py'>
#  2: <module 'igm.processes.time' from '/usr/local/lib/python3.12/dist-packages/igm/processes/time/__init__.py'>
#  3: <module 'igm.processes.thk' from '/usr/local/lib/python3.12/dist-packages/igm/processes/thk/__init__.py'>
# ------------------------------------------OUTPUTS Modules-------------------------------------------
#  0: <module 'igm.outputs.local' from '/usr/local/lib/python3.12/dist-packages/igm/outputs/local.py'>
#  1: <module 'igm.outputs.plot2d' from '/usr/local/lib/python3.12/dist-packages/igm/outputs/plot2d.py'>
# ----------------------------------------------------------------------------------------------------
# Found pretrained emulator in the igm package: pinnbp_10_4_cnn_16_32_2_1_a
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_1             │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 5)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, None,      │      1,472 │ input_1[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, None,      │          0 │ conv2d[0][0],     │
# │ (LeakyReLU)         │ None, 32)         │            │ conv2d_1[0][0],   │
# │                     │                   │            │ conv2d_2[0][0],   │
# │                     │                   │            │ conv2d_3[0][0],   │
# │                     │                   │            │ conv2d_4[0][0],   │
# │                     │                   │            │ conv2d_5[0][0],   │
# │                     │                   │            │ conv2d_6[0][0],   │
# │                     │                   │            │ conv2d_7[0][0],   │
# │                     │                   │            │ conv2d_8[0][0],   │
# │                     │                   │            │ conv2d_9[0][0],   │
# │                     │                   │            │ conv2d_10[0][0],  │
# │                     │                   │            │ conv2d_11[0][0],  │
# │                     │                   │            │ conv2d_12[0][0],  │
# │                     │                   │            │ conv2d_13[0][0],  │
# │                     │                   │            │ conv2d_14[0][0],  │
# │                     │                   │            │ conv2d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, None,      │          0 │ leaky_re_lu[0][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, None,      │      9,248 │ dropout[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[1][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, None,      │      9,248 │ dropout_1[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[2][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, None,      │      9,248 │ dropout_2[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[3][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, None,      │      9,248 │ dropout_3[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[4][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, None,      │      9,248 │ dropout_4[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[5][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, None,      │      9,248 │ dropout_5[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[6][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, None,      │      9,248 │ dropout_6[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[7][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, None,      │      9,248 │ dropout_7[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[8][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, None,      │      9,248 │ dropout_8[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[9][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, None,      │      9,248 │ dropout_9[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, None,      │          0 │ leaky_re_lu[10][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, None,      │      9,248 │ dropout_10[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, None,      │          0 │ leaky_re_lu[11][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, None,      │      9,248 │ dropout_11[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, None,      │          0 │ leaky_re_lu[12][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, None,      │      9,248 │ dropout_12[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, None,      │          0 │ leaky_re_lu[13][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, None,      │      9,248 │ dropout_13[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, None,      │          0 │ leaky_re_lu[14][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, None,      │      9,248 │ dropout_14[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, None,      │          0 │ leaky_re_lu[15][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, None,      │        660 │ dropout_15[0][0]  │
# │                     │ None, 20)         │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 140,852 (550.20 KB)
#  Trainable params: 140,852 (550.20 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# 2025-10-22 06:51:26.136910: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# W0000 00:00:1761115886.561434    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.618592    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.623789    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.624987    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.626241    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.627438    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.628706    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.665860    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.667207    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.668512    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.686796    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.688307    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.706384    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.707808    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.709301    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.805601    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.852774    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.936482    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.937933    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.939453    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.940968    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.942497    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.944029    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.945600    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115886.999811    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115887.001577    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115887.003339    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115887.005158    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115887.006967    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115887.008859    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115887.011144    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115887.013462    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115887.016556    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115887.020271    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115887.041923    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/tensor_util.py:522: RuntimeWarning: overflow encountered in cast
#   nparray = np.array(values, dtype=np_dt)
# W0000 00:00:1761115895.476558    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.478052    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.479915    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.514036    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.516464    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.518937    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.521312    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.523770    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.527450    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.531028    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.589832    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.679693    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.691351    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.701176    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.703306    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.713819    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.718353    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.733161    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.753566    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.756826    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.760267    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.764434    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.768636    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.774614    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.810365    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.817789    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.819559    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.821975    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.823372    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.824740    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.826084    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.828681    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.831181    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.832958    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.838012    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.839353    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.840671    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.842619    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.844427    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.846070    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.847971    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.850195    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.853167    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.855587    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.857392    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761115895.860199    2451 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# IGM , 🕒=06:51:49, 🔄=000100, ⏱ Time=0001926.5 yr, ⏳ Step=0.20 yr, ❄️  Volume=14.17 km³
# IGM , 🕒=06:51:59, 🔄=000200, ⏱ Time=0001944.5 yr, ⏳ Step=0.21 yr, ❄️  Volume=14.68 km³
# IGM , 🕒=06:52:09, 🔄=000300, ⏱ Time=0001963.2 yr, ⏳ Step=0.15 yr, ❄️  Volume=15.46 km³
# IGM , 🕒=06:52:20, 🔄=000400, ⏱ Time=0001980.8 yr, ⏳ Step=0.17 yr, ❄️  Volume=16.05 km³
# IGM , 🕒=06:52:30, 🔄=000500, ⏱ Time=0001999.1 yr, ⏳ Step=0.21 yr, ❄️  Volume=16.46 km³
# IGM , 🕒=06:52:32, 🔄=000505, ⏱ Time=0002000.0 yr, ⏳ Step=0.03 yr, ❄️  Volume=16.47 km³

# %% [markdown]
# ### Explore the output
#
# Each IGM run will generate a folder with the date as the parent folder and the time as a subfolder. For instance, after a few runs we could end up with the following structure:
#
# ```bash
# outputs
#   └───2025-04-07
#       ├─── 12-06-29
#       └─── 12-07-38
# ```

# %%
# !tree
# Out:
# .
# ├── data
# │   └── input-aletsch.nc
# ├── experiment
# │   ├── params_0.yaml
# │   ├── params_1.yaml
# │   └── params_2.yaml
# ├── glacier-modelling-2.ipynb
# ├── helper.py
# ├── outputs
# │   └── 2025-10-22
# │       └── 06-51-22
# │           ├── igm_run.log
# │           ├── output.nc
# │           ├── output_ts.nc
# │           ├── velbar_mag-1900.0.png
# │           ├── velbar_mag-1910.0.png
# │           ├── velbar_mag-1920.0.png
# │           ├── velbar_mag-1930.0.png
# │           ├── velbar_mag-1940.0.png
# │           ├── velbar_mag-1950.0.png
# │           ├── velbar_mag-1960.0.png
# │           ├── velbar_mag-1970.0.png
# │           ├── velbar_mag-1980.0.png
# │           ├── velbar_mag-1990.0.png
# │           └── velbar_mag-2000.0.png
# └── user
#     ├── code
#     │   └── processes
#     │       └── mysmb.py
#     └── conf
#         └── processes
#             └── mysmb.yaml
#
# 10 directories, 22 files

# %% [markdown]
# After the IGM run, you may have a quick look at the results by exploring:
#
# - Files `velbar_mag-19XX.0.png` that display ice speed and extent over the simulation time
# - `output.nc` that stores all the spatio-temporal output results
# - `output_ts.nc` that stores all time-dependent volume and area data
#
# Using the helper function, you can visualize the results:

# %%
from helper import *
import glob

# Find all output files
A = glob.glob('outputs/*/*/output.nc')
print(f"Found {len(A)} output file(s):", A)

if A:
    # Animate the last run
    animate_glacier_evolution(A[-1])
else:
    print("No output.nc files found. Please run the model first.")
# Out:
# Found 1 output file(s): ['outputs/2025-10-22/06-51-22/output.nc']

# %% [markdown]
# ### Analyzing the time series results
#
# Let's examine how the glacier ice volume and ice area evolved over the simulation period by reading the `output_ts.nc` file:

# %%
from helper import *
import glob
import os

# Find all time series files and select the most recent one
ts_files = sorted(glob.glob('outputs/*/*/output_ts.nc'))

if ts_files:
    # Get the absolute path to ensure it works from any directory
    ts_file = os.path.abspath(ts_files[-1])
    print(f"Found {len(ts_files)} time series file(s). Using: {ts_files[-1]}\n")
    # Analyze the time series from the most recent run
    analyze_time_series(ts_file)
else:
    print("No output_ts.nc file found. Please run the model first.")
# Out:
# Found 1 time series file(s). Using: outputs/2025-10-22/06-51-22/output_ts.nc
#
# Reading time series data from: /content/glamod/02_notebook/outputs/2025-10-22/06-51-22/output_ts.nc
# ============================================================
# SUMMARY STATISTICS
# ============================================================
#
# Ice Volume:
#   Initial: 13.75 km³
#   Final:   16.47 km³
#   Change:  2.72 km³
#
# Ice Area:
#   Initial: 84.35 km²
#   Final:   82.01 km²
#   Change:  -2.34 km²
# ============================================================

# %% [markdown]
# Congratulations! You have successfully run your first glacier model simulation using the IGM package. You can now explore different parameters and scenarios to see how they affect glacier dynamics. Happy modeling!
#
# You may now try to modify some parameters in the configuration file `params_0.yaml` and rerun the simulation to observe how changes impact the glacier's behavior.
#
# **Tips:** Create a new parameter file by copying `params_0.yaml` to `params_0_student.yaml` and modify it. Then run the simulation with the command `igm_run +experiment=params_0_student`.

# %% [markdown]
# ## Second run with IGM

# %% [markdown]
# The above example is somewhat limited. In a second run, we are making improvements using `params_1.yaml` instead of `params_0.yaml`:
#
# **First improvement:** Instead of using local data, we use the module `oggm_shop` to download all necessary data. The main advantage is that we can order any glacier using their RGI ID, and therefore get the data for any glacier on Earth!
#
# **Second improvement:** OGGM will download climate data (a time series), which will serve to generate a climate (temperature and precipitation in module `clim_oggm`) to compute a better Surface Mass Balance model. Note this parameter in the parameter file:
#
# ```yaml
#   clim_oggm:
#     clim_trend_array:
#       - ["time", "delta_temp", "prec_scal"]
#       - [ 1900,           0.0,         1.0]
#       - [ 2020,           0.0,         1.0]
#       - [ 2100,           4.0,         1.0]
# ```
#
# Similar to the previous method, this array assigns weights to modify precipitation and temperature series based on a *neutral* climate period, typically defined as 1960-1990. By adjusting the temperature offset in the `delta_temp` column, for example, a value of -2.0 would create a climate scenario for the 1960-1990 period that is 2 degrees cooler. Likewise, by modifying the precipitation scaling in the `prec_scal` column, a value of 1.5 would result in a climate scenario that has 150% of the precipitation compared to the 1960-1990 average.
#
# Finally, you can incorporate this parameter to provide global control for melt (note that the melt parameters in the PDD model are notoriously uncertain):
#
# ```yaml
#    melt_enhancer: 0.7
# ```
#
# Find more information about the generated climate [here](https://igm-model.org/latest/modules/processes/clim_oggm/).
#
# **Third improvement:** Instead of using the Simple Surface Mass Balance `smb_simple`, and now that we have climate available, we will use the `smb_oggm` SMB, which is a monthly temperature index model as described [here](https://igm-model.org/latest/modules/processes/smb_oggm/).
#
# First explore `params_1.yaml`, then run the following command, which will model the Glacier with RGI ID `RGI60-11.01450` (the Great Aletsch Glacier, Switzerland) from 2020 to 2100, assuming a temperature increase of 4 degrees by 2100 relative to 1960–1990:

# %%
! igm_run +experiment=params_1
# Out:
# 2025-10-22 06:52:46.825397: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-22 06:52:46.846924: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-22 06:52:46.852712: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-22 06:52:46.867033: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-22 06:52:47.984227: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761115971.273448    2942 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761115971.342805    2942 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761115971.343257    2942 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# -------------------------------------------------------------------CUDA Enviroment--------------------------------------------------------------------
# {
#   "cpu_compiler": "/usr/lib/llvm-17/bin/clang",
#   "cuda_version": "12.3",
#   "cudnn_version": "8",
#   "is_cuda_build": true,
#   "is_rocm_build": false,
#   "is_tensorrt_build": true
# }
# ----------------------------------------------------------------Available GPU Devices-----------------------------------------------------------------
# I0000 00:00:1761115971.343806    2942 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# {
#   "gpu_id": "/physical_device:GPU:0",
#   "device_type": "GPU",
#   "compute_capability": [
#     7,
#     5
#   ],
#   "device_name": "Tesla T4"
# }
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# I0000 00:00:1761115971.344994    2942 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761115971.345432    2942 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761115971.345687    2942 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761115971.446458    2942 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761115971.447063    2942 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761115971.447464    2942 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-10-22 06:52:51.447699: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 1 Physical GPUs, 1 Logical GPU
# ----------------------------------------------------------------------------------------------------
# -------------------------------------------INPUTS Modules-------------------------------------------
#  0: <module 'igm.inputs.oggm_shop' from '/usr/local/lib/python3.12/dist-packages/igm/inputs/oggm_shop/__init__.py'>
#  1: <module 'igm.inputs.local' from '/usr/local/lib/python3.12/dist-packages/igm/inputs/local.py'>
# -----------------------------------------PROCESSES Modules------------------------------------------
#  0: <module 'igm.processes.clim_oggm' from '/usr/local/lib/python3.12/dist-packages/igm/processes/clim_oggm/__init__.py'>
#  1: <module 'igm.processes.smb_oggm' from '/usr/local/lib/python3.12/dist-packages/igm/processes/smb_oggm/__init__.py'>
#  2: <module 'igm.processes.iceflow' from '/usr/local/lib/python3.12/dist-packages/igm/processes/iceflow/__init__.py'>
#  3: <module 'igm.processes.time' from '/usr/local/lib/python3.12/dist-packages/igm/processes/time/__init__.py'>
#  4: <module 'igm.processes.thk' from '/usr/local/lib/python3.12/dist-packages/igm/processes/thk/__init__.py'>
# ------------------------------------------OUTPUTS Modules-------------------------------------------
#  0: <module 'igm.outputs.local' from '/usr/local/lib/python3.12/dist-packages/igm/outputs/local.py'>
#  1: <module 'igm.outputs.plot2d' from '/usr/local/lib/python3.12/dist-packages/igm/outputs/plot2d.py'>
# ----------------------------------------------------------------------------------------------------
# Downloading salem-sample-data...
# 2025-10-22 06:52:56: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2025-10-22 06:52:56: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2025-10-22 06:52:56: oggm.cfg: Multiprocessing: using all available processors (N=2)
# 2025-10-22 06:52:56: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2025-10-22 06:52:56: oggm.utils: Downloading https://github.com/OGGM/oggm-sample-data/archive/e6da53aea8438a06d7702769e73fe5df8ab0d669.zip to /root/OGGM/download_cache/github.com/OGGM/oggm-sample-data/archive/e6da53aea8438a06d7702769e73fe5df8ab0d669.zip...
# |  -1.0 B Elapsed Time: 0:00:01
# 2025-10-22 06:52:59: oggm.workflow: init_glacier_directories from prepro level 3 on 1 glaciers.
# 2025-10-22 06:52:59: oggm.workflow: Execute entity tasks [gdir_from_prepro] on 1 glaciers
# 2025-10-22 06:52:59: oggm.utils: Downloading https://cluster.klima.uni-bremen.de/~oggm/gdirs/oggm_v1.6/exps/igm_v4/RGI70G/b_040/L3/RGI2000-v7.0-G-11/RGI2000-v7.0-G-11-02.tar to /root/OGGM/download_cache/cluster.klima.uni-bremen.de/~oggm/gdirs/oggm_v1.6/exps/igm_v4/RGI70G/b_040/L3/RGI2000-v7.0-G-11/RGI2000-v7.0-G-11-02.tar...
# 100% of 281.9 MiB |######################| Elapsed Time: 0:00:16 Time:  0:00:16
# 2025-10-22 06:53:17: oggm.utils: Downloading https://cluster.klima.uni-bremen.de/~fmaussion/misc/rgi7_data/00_rgi70_regions/00_rgi70_O1Regions/00_rgi70_O1Regions.dbf to /root/OGGM/download_cache/cluster.klima.uni-bremen.de/~fmaussion/misc/rgi7_data/00_rgi70_regions/00_rgi70_O1Regions/00_rgi70_O1Regions.dbf...
# 100% of   5.1 KiB |######################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2025-10-22 06:53:17: oggm.utils: Downloading https://cluster.klima.uni-bremen.de/~fmaussion/misc/rgi7_data/00_rgi70_regions/00_rgi70_O2Regions/00_rgi70_O2Regions.dbf to /root/OGGM/download_cache/cluster.klima.uni-bremen.de/~fmaussion/misc/rgi7_data/00_rgi70_regions/00_rgi70_O2Regions/00_rgi70_O2Regions.dbf...
# 100% of  28.7 KiB |######################| Elapsed Time: 0:00:00 Time:  0:00:00
# Found pretrained emulator in the igm package: pinnbp_10_4_cnn_16_32_2_1_a
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_1             │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 5)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, None,      │      1,472 │ input_1[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, None,      │          0 │ conv2d[0][0],     │
# │ (LeakyReLU)         │ None, 32)         │            │ conv2d_1[0][0],   │
# │                     │                   │            │ conv2d_2[0][0],   │
# │                     │                   │            │ conv2d_3[0][0],   │
# │                     │                   │            │ conv2d_4[0][0],   │
# │                     │                   │            │ conv2d_5[0][0],   │
# │                     │                   │            │ conv2d_6[0][0],   │
# │                     │                   │            │ conv2d_7[0][0],   │
# │                     │                   │            │ conv2d_8[0][0],   │
# │                     │                   │            │ conv2d_9[0][0],   │
# │                     │                   │            │ conv2d_10[0][0],  │
# │                     │                   │            │ conv2d_11[0][0],  │
# │                     │                   │            │ conv2d_12[0][0],  │
# │                     │                   │            │ conv2d_13[0][0],  │
# │                     │                   │            │ conv2d_14[0][0],  │
# │                     │                   │            │ conv2d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, None,      │          0 │ leaky_re_lu[0][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, None,      │      9,248 │ dropout[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[1][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, None,      │      9,248 │ dropout_1[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[2][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, None,      │      9,248 │ dropout_2[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[3][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, None,      │      9,248 │ dropout_3[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[4][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, None,      │      9,248 │ dropout_4[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[5][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, None,      │      9,248 │ dropout_5[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[6][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, None,      │      9,248 │ dropout_6[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[7][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, None,      │      9,248 │ dropout_7[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[8][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, None,      │      9,248 │ dropout_8[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[9][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, None,      │      9,248 │ dropout_9[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, None,      │          0 │ leaky_re_lu[10][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, None,      │      9,248 │ dropout_10[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, None,      │          0 │ leaky_re_lu[11][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, None,      │      9,248 │ dropout_11[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, None,      │          0 │ leaky_re_lu[12][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, None,      │      9,248 │ dropout_12[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, None,      │          0 │ leaky_re_lu[13][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, None,      │      9,248 │ dropout_13[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, None,      │          0 │ leaky_re_lu[14][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, None,      │      9,248 │ dropout_14[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, None,      │          0 │ leaky_re_lu[15][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, None,      │        660 │ dropout_15[0][0]  │
# │                     │ None, 20)         │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 140,852 (550.20 KB)
#  Trainable params: 140,852 (550.20 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# 2025-10-22 06:53:20.918630: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# W0000 00:00:1761116000.995324    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.045418    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.047025    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.048242    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.049513    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.050799    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.052197    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.058732    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.060109    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.061414    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.063949    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.065327    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.068198    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.069653    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.071194    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.086125    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.125666    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.127152    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.128732    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.130411    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.132388    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.134128    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.135804    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.151129    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.153040    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.154933    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.156915    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.158883    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.163270    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.165712    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.168303    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.171625    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116001.175706    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/tensor_util.py:522: RuntimeWarning: overflow encountered in cast
#   nparray = np.array(values, dtype=np_dt)
# W0000 00:00:1761116009.153163    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.154709    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.156733    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.166984    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.169645    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.172305    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.174986    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.177755    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.181971    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.186154    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.248849    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.252138    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.255780    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.259676    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.264153    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.269082    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.277756    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.281489    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.284747    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.289547    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.294167    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.331499    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.333003    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.334950    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.337630    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.339029    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.340459    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.341830    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.344734    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.347469    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.352112    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.353456    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.354832    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.356511    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.358406    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.360407    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.362766    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.366093    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.370267    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116009.374292    2942 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# IGM , 🕒=06:53:49, 🔄=000100, ⏱ Time=0001859.0 yr, ⏳ Step=0.32 yr, ❄️  Volume=7.41 km³
# IGM , 🕒=06:54:07, 🔄=000200, ⏱ Time=0001880.7 yr, ⏳ Step=0.17 yr, ❄️  Volume=10.07 km³
# IGM , 🕒=06:54:19, 🔄=000300, ⏱ Time=0001899.2 yr, ⏳ Step=0.19 yr, ❄️  Volume=12.07 km³
# IGM , 🕒=06:54:35, 🔄=000400, ⏱ Time=0001918.2 yr, ⏳ Step=0.19 yr, ❄️  Volume=14.46 km³
# IGM , 🕒=06:54:52, 🔄=000500, ⏱ Time=0001937.6 yr, ⏳ Step=0.22 yr, ❄️  Volume=16.33 km³
# IGM , 🕒=06:55:12, 🔄=000600, ⏱ Time=0001959.2 yr, ⏳ Step=0.21 yr, ❄️  Volume=18.06 km³
# IGM , 🕒=06:55:39, 🔄=000700, ⏱ Time=0001980.2 yr, ⏳ Step=0.20 yr, ❄️  Volume=19.85 km³
# IGM , 🕒=06:56:02, 🔄=000800, ⏱ Time=0002000.6 yr, ⏳ Step=0.21 yr, ❄️  Volume=20.96 km³
# IGM , 🕒=06:56:26, 🔄=000900, ⏱ Time=0002022.1 yr, ⏳ Step=0.23 yr, ❄️  Volume=20.92 km³
# IGM , 🕒=06:56:51, 🔄=001000, ⏱ Time=0002044.3 yr, ⏳ Step=0.23 yr, ❄️  Volume=22.04 km³
# IGM , 🕒=06:57:17, 🔄=001100, ⏱ Time=0002067.5 yr, ⏳ Step=0.24 yr, ❄️  Volume=21.34 km³
# IGM , 🕒=06:57:54, 🔄=001200, ⏱ Time=0002095.4 yr, ⏳ Step=0.39 yr, ❄️  Volume=17.66 km³
# IGM , 🕒=06:58:05, 🔄=001212, ⏱ Time=0002100.0 yr, ⏳ Step=0.21 yr, ❄️  Volume=16.86 km³

# %% [markdown]
# Running the code has created the following output files:

# %%
from helper import *
import glob

# Find all output files
A = glob.glob('outputs/*/*/output.nc')
print(f"Found {len(A)} output file(s):", A)

if A:
    # Animate the last run
    animate_glacier_evolution(A[-1])
else:
    print("No output.nc files found. Please run the model first.")
# Out:
# Found 2 output file(s): ['outputs/2025-10-22/06-51-22/output.nc', 'outputs/2025-10-22/06-52-51/output.nc']

# %% [markdown]
# ### Analyzing the time series results
#
# Let's examine how the glacier evolved under the climate scenario:

# %%
from helper import *
import glob
import os

# Find all time series files and select the most recent one
ts_files = sorted(glob.glob('outputs/*/*/output_ts.nc'))

if ts_files:
    # Get the absolute path to ensure it works from any directory
    ts_file = os.path.abspath(ts_files[-1])
    print(f"Found {len(ts_files)} time series file(s). Using: {ts_files[-1]}\n")
    # Analyze the time series from the most recent run
    analyze_time_series(ts_file)
else:
    print("No output_ts.nc file found. Please run the model first.")
# Out:
# Found 2 time series file(s). Using: outputs/2025-10-22/06-52-51/output_ts.nc
#
# Reading time series data from: /content/glamod/02_notebook/outputs/2025-10-22/06-52-51/output_ts.nc
# ============================================================
# SUMMARY STATISTICS
# ============================================================
#
# Ice Volume:
#   Initial: 0.00 km³
#   Final:   16.86 km³
#   Change:  16.86 km³
#
# Ice Area:
#   Initial: 0.00 km²
#   Final:   92.51 km²
#   Change:  92.51 km²
# ============================================================

# %% [markdown]
# ## Third run with IGM
#
# In a third run, we will bring 2 additional new features (explore the parameter file `params_2.yaml`):
#
# **First new feature:** Using a **custom SMB function** that is defined in the `user` folder. Explore the `user` folder and the parameter file `params_2.yaml` to see how custom code can be integrated.
#
# **Second new feature:** We activate a particle tracking module to simulate the displacement of virtual particles within the ice flow. These particles may represent debris or sediments that are transported by the glacier and are responsible for the formation of moraines. Our goal is to model the formation of the main moraine that developed during the Little Ice Age when the glacier reached its maximum extent.
#
# To achieve this, we have added in `params_2.yaml` two modules: `vert_flow` and `particles`. The `vert_flow` module computes vertical velocities (which is not done by default as it is not usually required), while the `particles` module tracks the trajectory of individual particles. It is possible to visualize the moraine formed by looking at the file `velbar_mag-XXXX.0.png`.
#
# Run the following command:

# %%
! igm_run +experiment=params_2
# Out:
# 2025-10-22 06:59:04.270706: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-22 06:59:04.292492: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-22 06:59:04.299276: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-22 06:59:04.317029: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-22 06:59:05.448003: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761116348.712735    4651 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761116348.760019    4651 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761116348.760355    4651 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# -------------------------------------------------------------------CUDA Enviroment--------------------------------------------------------------------
# {
#   "cpu_compiler": "/usr/lib/llvm-17/bin/clang",
#   "cuda_version": "12.3",
#   "cudnn_version": "8",
#   "is_cuda_build": true,
#   "is_rocm_build": false,
#   "is_tensorrt_build": true
# }
# ----------------------------------------------------------------Available GPU Devices-----------------------------------------------------------------
# I0000 00:00:1761116348.760835    4651 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# {
#   "gpu_id": "/physical_device:GPU:0",
#   "device_type": "GPU",
#   "compute_capability": [
#     7,
#     5
#   ],
#   "device_name": "Tesla T4"
# }
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# I0000 00:00:1761116348.761815    4651 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761116348.762162    4651 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761116348.762376    4651 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761116348.860625    4651 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761116348.861102    4651 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761116348.861397    4651 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-10-22 06:59:08.861579: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 1 Physical GPUs, 1 Logical GPU
# ----------------------------------------------------------------------------------------------------
# -------------------------------------------INPUTS Modules-------------------------------------------
#  0: <module 'igm.inputs.oggm_shop' from '/usr/local/lib/python3.12/dist-packages/igm/inputs/oggm_shop/__init__.py'>
#  1: <module 'igm.inputs.local' from '/usr/local/lib/python3.12/dist-packages/igm/inputs/local.py'>
# -----------------------------------------PROCESSES Modules------------------------------------------
#  0: <module 'mysmb' from '/content/glamod/02_notebook/user/code/processes/mysmb.py'>
#  1: <module 'igm.processes.iceflow' from '/usr/local/lib/python3.12/dist-packages/igm/processes/iceflow/__init__.py'>
#  2: <module 'igm.processes.time' from '/usr/local/lib/python3.12/dist-packages/igm/processes/time/__init__.py'>
#  3: <module 'igm.processes.thk' from '/usr/local/lib/python3.12/dist-packages/igm/processes/thk/__init__.py'>
#  4: <module 'igm.processes.vert_flow' from '/usr/local/lib/python3.12/dist-packages/igm/processes/vert_flow/__init__.py'>
#  5: <module 'igm.processes.particles' from '/usr/local/lib/python3.12/dist-packages/igm/processes/particles/__init__.py'>
# ------------------------------------------OUTPUTS Modules-------------------------------------------
#  0: <module 'igm.outputs.local' from '/usr/local/lib/python3.12/dist-packages/igm/outputs/local.py'>
#  1: <module 'igm.outputs.plot2d' from '/usr/local/lib/python3.12/dist-packages/igm/outputs/plot2d.py'>
# ----------------------------------------------------------------------------------------------------
# 2025-10-22 06:59:09: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2025-10-22 06:59:09: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2025-10-22 06:59:09: oggm.cfg: Multiprocessing: using all available processors (N=2)
# 2025-10-22 06:59:09: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2025-10-22 06:59:09: oggm.workflow: init_glacier_directories from prepro level 3 on 1 glaciers.
# 2025-10-22 06:59:09: oggm.workflow: Execute entity tasks [gdir_from_prepro] on 1 glaciers
# 2025-10-22 06:59:09: oggm.utils: Downloading https://cluster.klima.uni-bremen.de/~oggm/gdirs/oggm_v1.6/exps/igm_v2/RGI62/b_040/L3/RGI60-11/RGI60-11.01.tar to /root/OGGM/download_cache/cluster.klima.uni-bremen.de/~oggm/gdirs/oggm_v1.6/exps/igm_v2/RGI62/b_040/L3/RGI60-11/RGI60-11.01.tar...
# 100% of 154.6 MiB |######################| Elapsed Time: 0:00:09 Time:  0:00:09
# Found pretrained emulator in the igm package: pinnbp_10_4_cnn_16_32_2_1_a
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_1             │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 5)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, None,      │      1,472 │ input_1[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, None,      │          0 │ conv2d[0][0],     │
# │ (LeakyReLU)         │ None, 32)         │            │ conv2d_1[0][0],   │
# │                     │                   │            │ conv2d_2[0][0],   │
# │                     │                   │            │ conv2d_3[0][0],   │
# │                     │                   │            │ conv2d_4[0][0],   │
# │                     │                   │            │ conv2d_5[0][0],   │
# │                     │                   │            │ conv2d_6[0][0],   │
# │                     │                   │            │ conv2d_7[0][0],   │
# │                     │                   │            │ conv2d_8[0][0],   │
# │                     │                   │            │ conv2d_9[0][0],   │
# │                     │                   │            │ conv2d_10[0][0],  │
# │                     │                   │            │ conv2d_11[0][0],  │
# │                     │                   │            │ conv2d_12[0][0],  │
# │                     │                   │            │ conv2d_13[0][0],  │
# │                     │                   │            │ conv2d_14[0][0],  │
# │                     │                   │            │ conv2d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, None,      │          0 │ leaky_re_lu[0][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, None,      │      9,248 │ dropout[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[1][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, None,      │      9,248 │ dropout_1[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[2][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, None,      │      9,248 │ dropout_2[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[3][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, None,      │      9,248 │ dropout_3[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[4][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, None,      │      9,248 │ dropout_4[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[5][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, None,      │      9,248 │ dropout_5[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[6][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, None,      │      9,248 │ dropout_6[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[7][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, None,      │      9,248 │ dropout_7[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[8][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, None,      │      9,248 │ dropout_8[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[9][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, None,      │      9,248 │ dropout_9[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, None,      │          0 │ leaky_re_lu[10][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, None,      │      9,248 │ dropout_10[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, None,      │          0 │ leaky_re_lu[11][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, None,      │      9,248 │ dropout_11[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, None,      │          0 │ leaky_re_lu[12][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, None,      │      9,248 │ dropout_12[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, None,      │          0 │ leaky_re_lu[13][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, None,      │      9,248 │ dropout_13[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, None,      │          0 │ leaky_re_lu[14][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, None,      │      9,248 │ dropout_14[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, None,      │          0 │ leaky_re_lu[15][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, None,      │        660 │ dropout_15[0][0]  │
# │                     │ None, 20)         │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 140,852 (550.20 KB)
#  Trainable params: 140,852 (550.20 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# 2025-10-22 06:59:21.850384: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# W0000 00:00:1761116361.932395    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116361.977817    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116361.979489    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116361.980708    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116361.981947    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116361.983191    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116361.984490    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116361.991103    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116361.992429    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116361.993746    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116361.996580    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116361.997941    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.000773    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.002233    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.003776    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.017473    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.052927    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.054456    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.056055    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.057648    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.059269    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.060882    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.062559    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.076912    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.078876    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.080768    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.082728    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.084691    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.088872    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.091279    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.093886    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.097231    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116362.101264    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/tensor_util.py:522: RuntimeWarning: overflow encountered in cast
#   nparray = np.array(values, dtype=np_dt)
# W0000 00:00:1761116370.285012    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.286597    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.288588    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.297084    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.299735    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.302352    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.304986    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.307773    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.311879    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.315902    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.358212    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.361366    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.364524    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.366719    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.370773    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.375585    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.379844    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.383449    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.386566    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.391200    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.395655    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.421040    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.432688    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.434584    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.437152    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.438630    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.439987    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.441322    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.444145    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.446885    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.450292    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.451666    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.452992    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.454743    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.456582    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.458494    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.460741    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.463867    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.467307    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761116370.470272    4651 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# IGM , 🕒=06:59:59, 🔄=000100, ⏱ Time=0002078.2 yr, ⏳ Step=0.37 yr, ❄️  Volume=9.56 km³, # Particles=300
# IGM , 🕒=07:00:17, 🔄=000163, ⏱ Time=0002100.0 yr, ⏳ Step=0.24 yr, ❄️  Volume=11.38 km³, # Particles=545
